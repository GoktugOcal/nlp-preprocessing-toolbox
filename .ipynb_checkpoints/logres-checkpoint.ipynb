# %%
from sklearn import linear_model, metrics
import numpy as np
import pandas as pd
import math

from tqdm import tqdm

import matplotlib.pyplot as plt
import string

from nlp_preprocessing_toolbox.helper import *
from nlp_preprocessing_toolbox.helper import __fixation

# %%
df_raw = sentence_splitter_load_and_parse_corpus()
# Out:
# 	Parsing the corpus.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7803/7803 [00:00<00:00, 29445.64it/s]

# %% [markdown]
# # Naive Bayes Sentence Splitting

# %%
time_lags = [-1,+1]

for col in time_lags:
    if col >= 0: df_raw["t+"+str(col)] = df_raw.char.shift(col)
    else: df_raw["t"+str(col)] = df_raw.char.shift(col)

df_raw = df_raw.dropna()

for col in time_lags:
    if col >= 0: df_raw["t+"+str(col)] = df_raw["t+"+str(col)].astype(str)
    else: ddf_raw["t"+str(col)] = df_raw["t+"+str(col)].astype(str)

df_raw["char"] = df_raw["char"].astype(str)

# %%
time_cols = []
for col in time_lags:
    if col >= 0: time_cols.append("t+"+str(col))
    else: time_cols.append("t"+str(col))

# %%
# df_raw["text"] = [row["t-2"] + row["t-1"] + row["char"] + row["t+1"] + row["t+2"] for i, row in df_raw.iterrows()]
df_raw["text"] = [row["t-1"] + row["char"] + row["t+1"] for i, row in df_raw.iterrows()]

# %%
punc_df = df_raw[df_raw["char"].isin(list(string.punctuation))].reset_index(drop=True)
punc_df
# Out:
#       char  label t-1 t+1 text
# 0        .      1       z   .z
# 1        .      1       m   .m
# 2        .      1       ı   .ı
# 3        ,      0       m   ,m
# 4        '      0   y   a  y'a
# ...    ...    ...  ..  ..  ...
# 20313    ,      0       z   ,z
# 20314    .      1       z   .z
# 20315    "      0   H      H"
# 20316    .      1       r   .r
# 20317    .      1       ı   .ı
#
# [20318 rows x 5 columns]

# %%
prob_df = pd.DataFrame(columns = sorted(list(set(punc_df[["char"] + time_cols].values.reshape(-1,1).T[0])), key = lambda x: x), index = [0,1])

p_cls = {
    0:len(punc_df[punc_df.label == 0]) / len(punc_df)
    1:len(punc_df[punc_df.label == 1]) / len(punc_df)
}

for idx in prob_df.index:
    df_class = punc_df[punc_df.label == idx]
    chars = df_class[["char"] + time_cols].values.reshape(-1,1).T[0]
    no_uniq_chars = len(set(chars))
    total_c = len(chars)
    
    for col in prob_df.columns:
        char_c = len(chars[chars == col])
        prob_df.iloc[idx][col] = math.log((char_c + 1) / (total_c + no_uniq_chars)) * p_cls[idx]

# %%
preds = []
prob_dict = prob_df.to_dict()
for idx, row in tqdm(punc_df.iterrows()):
    char_prob_dict = {}
    for cls in [0,1]:
        values = list(map(lambda x: prob_dict[x][cls], list(row.text)))
        char_prob_dict[cls] = np.prod(values)
    preds.append(max(char_prob_dict, key=char_prob_dict.get))
# Out:
# 20318it [00:01, 18499.05it/s]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_true = punc_df["label"].values
y_pred = preds
sns.heatmap(confusion_matrix(y_true, y_pred), annot=True)
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

print("Acc:",round(((tn + tp) / (tp + tn + fp + fn)) * 100,2))
print("Pre:",round(((tp) / (fp + tp)) * 100,2))
print("Rec:",round(((tp) / (fn + tp)) * 100,2))
# Out:
# Acc: 88.11
# Pre: 76.29
# Rec: 97.1

# %% [markdown]
# ## Splitting

# %%
text = '''Saçma ve Gereksiz Bir Yazı.
Bakkaldan 5 TL'lik 2 çikola-
ta al. 12.02.2018 tarihinde saat tam 15:45'te yap-
malıyız bu işi. Tamam mı? Benimle esatmahmutbayol@gmail.com 
adresinden iletişime geçebilirsin. Yarışta 1. oldu. Doç. Dr. 
Esat Bayol'un(Böyle bir ünvanım yok!) yanından geliyorum.
12 p.m. mi yoksa 12 a.m. mi? 100 milyon insan gelmiş! www.deneme.com.tr 
adresinden sitemizi inceleyebilirsin. 24 Eylül 2018 Pazartesi günü ge-
lecekmiş. 19 Mayıs'ı coşkuyla kutladık.
Sonra dedi ki "Ben seni sevmiyorum."'''


text = __fixation(text).replace("\n", " ")

# %%
lines = []
for idx, char in enumerate(text):
    row = {
        "char" : char
    }
    lines.append(row)

df_text = pd.DataFrame.from_records(lines)


def preprocess(df_raw):
    time_lags = [-1,+1]

    for col in time_lags:
        if col >= 0: df_raw["t+"+str(col)] = df_raw.char.shift(col)
        else: df_raw["t"+str(col)] = df_raw.char.shift(col)

    df_raw = df_raw.dropna()
    
    time_lags = [-1,1] 
    for col in time_lags:
        if col >= 0: df_raw["t+"+str(col)] = df_raw["t+"+str(col)].astype(str)
        else: df_raw["t"+str(col)] = df_raw["t"+str(col)].astype(str)

    df_raw["char"] = df_raw["char"].astype(str)
    df_raw["text"] = [row["t-1"] + row["char"] + row["t+1"] for i, row in df_raw.iterrows()]
    
    return df_raw

df_text = preprocess(df_text)
df_text
# Out:
# /tmp/ipykernel_19950/2479225002.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: df_raw["t"+str(col)] = df_raw["t"+str(col)].astype(str)
# /tmp/ipykernel_19950/2479225002.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if col >= 0: df_raw["t+"+str(col)] = df_raw["t+"+str(col)].astype(str)
# /tmp/ipykernel_19950/2479225002.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw["char"] = df_raw["char"].astype(str)
# /tmp/ipykernel_19950/2479225002.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw["text"] = [row["t-1"] + row["char"] + row["t+1"] for i, row in df_raw.iterrows()]
#     char t-1 t+1 text
# 1      a   ç   S  çaS
# 2      ç   m   a  mça
# 3      m   a   ç  amç
# 4      a       m   am
# 5          v   a  v a
# ..   ...  ..  ..  ...
# 500    o   r   y  roy
# 501    r   u   o  uro
# 502    u   m   r  mur
# 503    m   .   u  .mu
# 504    .   "   m  ".m
#
# [504 rows x 4 columns]

# %%
preds = []
prob_dict = prob_df.to_dict()
for idx, row in tqdm(df_text.iterrows()):
    if row["char"] in list(string.punctuation):
        try:
            char_prob_dict = {}
            for cls in [0,1]:
                values = list(map(lambda x: prob_dict[x][cls], list(row.text)))
                char_prob_dict[cls] = np.prod(values)
            preds.append(max(char_prob_dict, key=char_prob_dict.get))
        except:
            preds.append(0)
    else:
        preds.append(0)
# Out:
# 504it [00:00, 15314.00it/s]

# %%
df_text["label"] = preds

# %%
tokens = []
last_idx = 0
temp = ""
for idx, row in df_text.iterrows():
    if row.label == 0: temp += row.char
    elif row.label == 1:
        temp += row.char
        tokens.append(temp)
        temp = ""
        last_idx = idx

# %%
tokens
# Out:
# ['açma ve Gereksiz Bir Yazı.',
#  " Bakkaldan 5 TL'lik 2 çikolata  al.",
#  ' 12.',
#  '02.',
#  "2018 tarihinde saat tam 15:45'te yapmalıyız  bu işi.",
#  ' Tamam mı?',
#  ' Benimle esatmahmutbayol@gmail.',
#  'com  adresinden iletişime geçebilirsin.',
#  ' Yarışta 1.',
#  ' oldu.',
#  ' Doç.',
#  ' Dr.',
#  "  Esat Bayol'un(Böyle bir ünvanım yok!)",
#  ' yanından geliyorum.',
#  ' 12 p.',
#  'm.',
#  ' mi yoksa 12 a.',
#  'm.',
#  ' mi?',
#  ' 100 milyon insan gelmiş!',
#  ' www.deneme.',
#  'com.',
#  'tr  adresinden sitemizi inceleyebilirsin.',
#  ' 24 Eylül 2018 Pazartesi günü gelecekmiş.',
#  "  19 Mayıs'ı coşkuyla kutladık.",
#  ' Sonra dedi ki "Ben seni sevmiyorum.']

# %% [markdown]
# # Logistic Regression

# %%
df_raw = pd.read_csv('example.csv')

# df_add = df_raw[(df_raw["#is it number"] == True) & (df_raw["#is next char punc"] == True)]
# for i in range(100):
#     df_raw = pd.concat([df_raw,df_add])

df = df_raw.copy()
df = df[df.columns[1:]]
df = df.astype(int)

# %%
df_raw.head()
# Out:
#   char  #is it number  #is it punctuation  #is it period  #is next whitespace  \
# 0    1           True               False          False                False
# 1    9           True               False          False                False
# 2    3           True               False          False                False
# 3    6           True               False          False                 True
# 4    y          False               False          False                False
#
#    #is previos char number  #is next char number  #is next char period  label
# 0                    False                  True                 False      0
# 1                     True                  True                 False      0
# 2                     True                  True                 False      0
# 3                     True                  True                 False      1
# 4                    False                 False                 False      0

# %%
train_test_split = int(len(df)*0.8)
dfTrain, dfTest = df[0:train_test_split], df[train_test_split:]

X_train = dfTrain.values[:,0:-1]
y_train = dfTrain.values[:,-1]

X_test = dfTest.values[:,0:-1]
y_test = dfTest.values[:,-1]

# %%
logr = linear_model.LogisticRegression()
logr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
confusion_matrix = metrics.plot_confusion_matrix(logr, X_test, y_test, cmap = "GnBu")
plt.show()
# Out:
# C:\Users\gocal\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
text = '''Çünkü ben de o yaşadığı çevreyi kirleterek bozulmasına neden olan, tüm uyarılara
kulağını tıkayan soya aitim. Kimileri buna kader diyordu, kimileri unut. Bu da
zaman ister, emek ister. İki veli dokunulsa ağlayacaktı. Bu meslek böyledir.
Filmde kamburunu çıkarmış eski Yugoslav lideri, iki kişinin arasında elleri
önden bağlı, cezaevi avlusunda yürüyor. Sabahları hiçbir şey yemeden içmeden,
paldür küldür çıkıyorum evden. Bu albüm hit şarkı çıkarmaz, dedim.
12.02.2018 tarihinde saat tam 15:45'te burada ol.'''

text = '''Saçma ve Gereksiz Bir Yazı.
Bakkaldan 5 TL'lik 2 çikola-
ta al. 12.02.2018 tarihinde saat tam 15:45'te yap-
malıyız bu işi. Tamam mı? Benimle esatmahmutbayol@gmail.com 
adresinden iletişime geçebilirsin. Yarışta 1. oldu. Doç. Dr. 
Esat Bayol'un(Böyle bir ünvanım yok!) yanından geliyorum.
12 p.m. mi yoksa 12 a.m. mi? 100 milyon insan gelmiş! www.deneme.com.tr 
adresinden sitemizi inceleyebilirsin. 24 Eylül 2018 Pazartesi günü ge-
lecekmiş. 19 Mayıs'ı coşkuyla kutladık.
Sonra dedi ki "Ben seni sevmiyorum."'''

text = __fixation(text)

text = " " + text.replace("\n", " ") + " "
lines = []
for idx, char in enumerate(text):

    isItPunc, isItPeriod, isItWhitespace, isNextWhitespace, isPrevNumber, isNextNumber, isNextPunc, isItNum, isNextPeriod = \
        False, False, False, False, False, False, False, False, False
    
    if char != " " and idx != 0 and idx != len(text)-1:
        if char in string.punctuation                   : isItPunc = True
        if char == "."                                  : isItPeriod = True
        if char.isnumeric()                             : isItNum = True
        if text[idx+1] == " "                           : isNextWhitespace = True
        if text[idx+1] == "."                           : isNextPeriod = True
        if text[idx-1].isnumeric()                      : isPrevNumber = True
        if text[idx+1].isnumeric()                      : isNextNumber = True
        if text[idx+1] in string.punctuation            : isNextPunc = True

        row = {
                "char" : char,
                "#is it number" : isItNum,
                "#is it punctuation" : isItPunc,
                "#is it period" : isItPeriod,
                "#is next whitespace" : isNextWhitespace,
                "#is previos char number" : isPrevNumber,
                "#is next char number" : isNextNumber,
#                 "#is next char punc" : isNextPunc,
                "#is next char period" : isNextPeriod,
        }
        lines.append(row)

df_text = pd.DataFrame.from_records(lines)
df_real_test = df_text.values[:,1:]
df_real_test
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, True],
#        [False, True, True, ..., False, False, False],
#        [False, True, False, ..., False, False, False]], dtype=object)

# %%
pred = logr.predict(df_real_test)

# %%
df_text["label"] = pred
df_text
# Out:
#     char  #is it number  #is it punctuation  #is it period  \
# 0      S          False               False          False
# 1      a          False               False          False
# 2      ç          False               False          False
# 3      m          False               False          False
# 4      a          False               False          False
# ..   ...            ...                 ...            ...
# 427    r          False               False          False
# 428    u          False               False          False
# 429    m          False               False          False
# 430    .          False                True           True
# 431    "          False                True          False
#
#      #is next whitespace  #is previos char number  #is next char number  \
# 0                  False                    False                 False
# 1                  False                    False                 False
# 2                  False                    False                 False
# 3                  False                    False                 False
# 4                   True                    False                 False
# ..                   ...                      ...                   ...
# 427                False                    False                 False
# 428                False                    False                 False
# 429                False                    False                 False
# 430                False                    False                 False
# 431                 True                    False                 False
#
#      #is next char period  label
# 0                   False      0
# 1                   False      0
# 2                   False      0
# 3                   False      0
# 4                   False      1
# ..                    ...    ...
# 427                 False      0
# 428                 False      0
# 429                  True      1
# 430                 False      0
# 431                 False      1
#
# [432 rows x 9 columns]

# %%
tokens = []
last_idx = 0
temp = ""
for idx, row in df_text.iterrows():
    if row.label == 0: temp += row.char
    elif row.label == 1:
        temp += row.char
        tokens.append(temp)
        temp = ""
        last_idx = idx

# %%
tokens
# Out:
# ['Saçma',
#  've',
#  'Gereksiz',
#  'Bir',
#  'Yazı',
#  '.',
#  'Bakkaldan',
#  '5',
#  "TL'lik",
#  '2',
#  'çikolata',
#  'al',
#  '.',
#  '12',
#  '.02',
#  '.2018',
#  'tarihinde',
#  'saat',
#  'tam',
#  "15:45'te",
#  'yapmalıyız',
#  'bu',
#  'işi',
#  '.',
#  'Tamam',
#  'mı?',
#  'Benimle',
#  'esatmahmutbayol@gmail',
#  '.com',
#  'adresinden',
#  'iletişime',
#  'geçebilirsin',
#  '.',
#  'Yarışta',
#  '1',
#  '.',
#  'oldu',
#  '.',
#  'Doç',
#  '.',
#  'Dr',
#  '.',
#  'Esat',
#  "Bayol'un(Böyle",
#  'bir',
#  'ünvanım',
#  'yok!)',
#  'yanından',
#  'geliyorum',
#  '.',
#  '12',
#  'p',
#  '.m',
#  '.',
#  'mi',
#  'yoksa',
#  '12',
#  'a',
#  '.m',
#  '.',
#  'mi?',
#  '100',
#  'milyon',
#  'insan',
#  'gelmiş!',
#  'www',
#  '.deneme',
#  '.com',
#  '.tr',
#  'adresinden',
#  'sitemizi',
#  'inceleyebilirsin',
#  '.',
#  '24',
#  'Eylül',
#  '2018',
#  'Pazartesi',
#  'günü',
#  'gelecekmiş',
#  '.',
#  '19',
#  "Mayıs'ı",
#  'coşkuyla',
#  'kutladık',
#  '.',
#  'Sonra',
#  'dedi',
#  'ki',
#  '"Ben',
#  'seni',
#  'sevmiyorum',
#  '."']

# %%
df_text[50:100]
# Out:
#    char  #is it number  #is it punctuation  #is it period  \
# 50    .          False                True           True
# 51    1           True               False          False
# 52    2           True               False          False
# 53    .          False                True           True
# 54    0           True               False          False
# 55    2           True               False          False
# 56    .          False                True           True
# 57    2           True               False          False
# 58    0           True               False          False
# 59    1           True               False          False
# 60    8           True               False          False
# 61    t          False               False          False
# 62    a          False               False          False
# 63    r          False               False          False
# 64    i          False               False          False
# 65    h          False               False          False
# 66    i          False               False          False
# 67    n          False               False          False
# 68    d          False               False          False
# 69    e          False               False          False
# 70    s          False               False          False
# 71    a          False               False          False
# 72    a          False               False          False
# 73    t          False               False          False
# 74    t          False               False          False
# 75    a          False               False          False
# 76    m          False               False          False
# 77    1           True               False          False
# 78    5           True               False          False
# 79    :          False                True          False
# 80    4           True               False          False
# 81    5           True               False          False
# 82    '          False                True          False
# 83    t          False               False          False
# 84    e          False               False          False
# 85    y          False               False          False
# 86    a          False               False          False
# 87    p          False               False          False
# 88    m          False               False          False
# 89    a          False               False          False
# 90    l          False               False          False
# 91    ı          False               False          False
# 92    y          False               False          False
# 93    ı          False               False          False
# 94    z          False               False          False
# 95    b          False               False          False
# 96    u          False               False          False
# 97    i          False               False          False
# 98    ş          False               False          False
# 99    i          False               False          False
#
#     #is next whitespace  #is previos char number  #is next char number  \
# 50                 True                    False                 False
# 51                False                    False                  True
# 52                False                     True                 False
# 53                False                     True                  True
# 54                False                    False                  True
# 55                False                     True                 False
# 56                False                     True                  True
# 57                False                    False                  True
# 58                False                     True                  True
# 59                False                     True                  True
# 60                 True                     True                 False
# 61                False                    False                 False
# 62                False                    False                 False
# 63                False                    False                 False
# 64                False                    False                 False
# 65                False                    False                 False
# 66                False                    False                 False
# 67                False                    False                 False
# 68                False                    False                 False
# 69                 True                    False                 False
# 70                False                    False                 False
# 71                False                    False                 False
# 72                False                    False                 False
# 73                 True                    False                 False
# 74                False                    False                 False
# 75                False                    False                 False
# 76                 True                    False                 False
# 77                False                    False                  True
# 78                False                     True                 False
# 79                False                     True                  True
# 80                False                    False                  True
# 81                False                     True                 False
# 82                False                     True                 False
# 83                False                    False                 False
# 84                 True                    False                 False
# 85                False                    False                 False
# 86                False                    False                 False
# 87                False                    False                 False
# 88                False                    False                 False
# 89                False                    False                 False
# 90                False                    False                 False
# 91                False                    False                 False
# 92                False                    False                 False
# 93                False                    False                 False
# 94                 True                    False                 False
# 95                False                    False                 False
# 96                 True                    False                 False
# 97                False                    False                 False
# 98                False                    False                 False
# 99                False                    False                 False
#
#     #is next char period  label
# 50                 False      1
# 51                 False      0
# 52                  True      1
# 53                 False      0
# 54                 False      0
# 55                  True      1
# 56                 False      0
# 57                 False      0
# 58                 False      0
# 59                 False      0
# 60                 False      1
# 61                 False      0
# 62                 False      0
# 63                 False      0
# 64                 False      0
# 65                 False      0
# 66                 False      0
# 67                 False      0
# 68                 False      0
# 69                 False      1
# 70                 False      0
# 71                 False      0
# 72                 False      0
# 73                 False      1
# 74                 False      0
# 75                 False      0
# 76                 False      1
# 77                 False      0
# 78                 False      0
# 79                 False      0
# 80                 False      0
# 81                 False      0
# 82                 False      0
# 83                 False      0
# 84                 False      1
# 85                 False      0
# 86                 False      0
# 87                 False      0
# 88                 False      0
# 89                 False      0
# 90                 False      0
# 91                 False      0
# 92                 False      0
# 93                 False      0
# 94                 False      1
# 95                 False      0
# 96                 False      1
# 97                 False      0
# 98                 False      0
# 99                  True      1
